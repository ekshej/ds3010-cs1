# %% [markdown]
# # Case Study 1 : Collecting Data from Twitter
#
# Due Date: 1/27/2020, **BEFORE the beginning of class at 11:00am**
#
# ## **NOTE: There are *always* last minute issues submitting the case studies.  DO NOT WAIT UNTIL THE LAST MINUTE!**

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/en/thumb/9/9f/Twitter_bird_logo_2012.svg/220px-Twitter_bird_logo_2012.svg.png">

# %% [markdown]
# **TEAM Members:** Please EDIT this cell and add the names of all the team members in your team
#
#     Irean Ali
#
#     Achu Balasubramanian
#
#     Josh Lovering
#
#     ...

# %% [markdown]
# **Suggested Readings:**
# * Chapter 1 and Chapter 9 of the book "Mining the Social Web" can help a lot if you get stuck.
# * In fact, it is intentional that many of these questions can be answered directly from there (except for question 4)!
# * The idea is to ease you into the case studies :-)
#
# **Don't forget!**
# * You will need to install the python-twitter library to access the Twitter API
#  * pip install twitter
#
#
# ** NOTE **
# * **Please don't forget to save the notebook frequently when working in IPython Notebook, otherwise the changes you made can be lost**.

# %% [markdown]
# # Problem 1: Sampling Twitter Data with Streaming API about a certain topic

# %% [markdown]
# * Select a topic that you are interested in, for example, "WPI" or "Lady Gaga"
# * Use Twitter Streaming API to sample a collection of tweets about this topic in real time. (It would be recommended that the number of tweets should be larger than 200, but smaller than 1 million.
# * Store the tweets you downloaded into a local file (txt file or json file)

# %%
import twitter
#---------------------------------------------
# Define a Function to Login Twitter API
def oauth_login():
    # Prof. Paffenroth has a developer account for the class.  He will provide the Twitter access tokens for
    # each team
    # See https://developer.twitter.com/docs/auth/oauth for more information 
    # on Twitter's OAuth implementation.
    
    CONSUMER_KEY = "QoTiAk8g8Hm9Zhejyt1GxF9Bp"
    CONSUMER_SECRET = "Lj6Hg1XlDcKeT2pFNS330vN7RqgRzxHpsUovESMd9braCZ4WGO"
    # Open Authorizan
    OAUTH_TOKEN = "571213367-dPdnChuVRjwRHoqfH0pi15IbgGhJmRoKxJjrP9wD"
    OAUTH_TOKEN_SECRET = "3cp8koRc8EKcVn3DkI0HoGquXJWMnAYgU7pzMiMnNq3jq"
    
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                               CONSUMER_KEY, CONSUMER_SECRET)
    
    twitter_api = twitter.Twitter(auth=auth)
    return twitter_api

twitter_api = oauth_login()
print(twitter_api)
#----------------------------------------------
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary
# Out:
# <twitter.api.Twitter object at 0x00000235F78F4508>

# %%
WORLD_WOE_ID = 1
#Where on earth - entire world
US_WOE_ID = 23424977
#retrieve world and US trends
#Where on earth - United States
world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
#creates listt of Python dictionaries from API
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
print(world_trends)
print()
print(us_trends)
# Out:
# [{'trends': [{'name': '#WOLLIV', 'url': 'http://twitter.com/search?q=%23WOLLIV', 'promoted_content': None, 'query': '%23WOLLIV', 'tweet_volume': 33499}, {'name': '#coronovirus', 'url': 'http://twitter.com/search?q=%23coronovirus', 'promoted_content': None, 'query': '%23coronovirus', 'tweet_volume': 90680}, {'name': '#RutoSpeaks', 'url': 'http://twitter.com/search?q=%23RutoSpeaks', 'promoted_content': None, 'query': '%23RutoSpeaks', 'tweet_volume': 25569}, {'name': '#COAC2020P4', 'url': 'http://twitter.com/search?q=%23COAC2020P4', 'promoted_content': None, 'query': '%23COAC2020P4', 'tweet_volume': None}, {'name': '#ThankYouJimin', 'url': 'http://twitter.com/search?q=%23ThankYouJimin', 'promoted_content': None, 'query': '%23ThankYouJimin', 'tweet_volume': 248515}, {'name': 'Jim Lehrer', 'url': 'http://twitter.com/search?q=%22Jim+Lehrer%22', 'promoted_content': None, 'query': '%22Jim+Lehrer%22', 'tweet_volume': 23892}, {'name': 'Prince Charles', 'url': 'http://twitter.com/search?q=%22Prince+Charles%22', 'promoted_content': None, 'query': '%22Prince+Charles%22', 'tweet_volume': 77274}, {'name': 'Church of England', 'url': 'http://twitter.com/search?q=%22Church+of+England%22', 'promoted_content': None, 'query': '%22Church+of+England%22', 'tweet_volume': 17448}, {'name': 'MY BOO BY CNCO', 'url': 'http://twitter.com/search?q=%22MY+BOO+BY+CNCO%22', 'promoted_content': None, 'query': '%22MY+BOO+BY+CNCO%22', 'tweet_volume': 67995}, {'name': 'Damso', 'url': 'http://twitter.com/search?q=Damso', 'promoted_content': None, 'query': 'Damso', 'tweet_volume': 21172}, {'name': '#الاهلي_الرايد_الدوري', 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D8%A7%D9%84%D8%B1%D8%A7%D9%8A%D8%AF_%D8%A7%D9%84%D8%AF%D9%88%D8%B1%D9%8A', 'promoted_content': None, 'query': '%23%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D8%A7%D9%84%D8%B1%D8%A7%D9%8A%D8%AF_%D8%A7%D9%84%D8%AF%D9%88%D8%B1%D9%8A', 'tweet_volume': 35349}, {'name': '#benimkahramanım', 'url': 'http://twitter.com/search?q=%23benimkahraman%C4%B1m', 'promoted_content': None, 'query': '%23benimkahraman%C4%B1m', 'tweet_volume': 11101}, {'name': '#الشباب_والم', 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B4%D8%A8%D8%A7%D8%A8_%D9%88%D8%A7%D9%84%D9%85', 'promoted_content': None, 'query': '%23%D8%A7%D9%84%D8%B4%D8%A8%D8%A7%D8%A8_%D9%88%D8%A7%D9%84%D9%85', 'tweet_volume': None}, {'name': '#OTDirecto23E', 'url': 'http://twitter.com/search?q=%23OTDirecto23E', 'promoted_content': None, 'query': '%23OTDirecto23E', 'tweet_volume': 103109}, {'name': '#colourpop9milli', 'url': 'http://twitter.com/search?q=%23colourpop9milli', 'promoted_content': None, 'query': '%23colourpop9milli', 'tweet_volume': 11325}, {'name': '#DoomsdayClock', 'url': 'http://twitter.com/search?q=%23DoomsdayClock', 'promoted_content': None, 'query': '%23DoomsdayClock', 'tweet_volume': 26289}, {'name': '#kupanınyolu', 'url': 'http://twitter.com/search?q=%23kupan%C4%B1nyolu', 'promoted_content': None, 'query': '%23kupan%C4%B1nyolu', 'tweet_volume': None}, {'name': '#OroBTSColombia', 'url': 'http://twitter.com/search?q=%23OroBTSColombia', 'promoted_content': None, 'query': '%23OroBTSColombia', 'tweet_volume': 43196}, {'name': '#EverythingIWantedMusicVideo', 'url': 'http://twitter.com/search?q=%23EverythingIWantedMusicVideo', 'promoted_content': None, 'query': '%23EverythingIWantedMusicVideo', 'tweet_volume': 14238}, {'name': '#DragRace', 'url': 'http://twitter.com/search?q=%23DragRace', 'promoted_content': None, 'query': '%23DragRace', 'tweet_volume': 29618}, {'name': '#MasterChefIt', 'url': 'http://twitter.com/search?q=%23MasterChefIt', 'promoted_content': None, 'query': '%23MasterChefIt', 'tweet_volume': None}, {'name': '#ابناء_الدوحه', 'url': 'http://twitter.com/search?q=%23%D8%A7%D8%A8%D9%86%D8%A7%D8%A1_%D8%A7%D9%84%D8%AF%D9%88%D8%AD%D9%87', 'promoted_content': None, 'query': '%23%D8%A7%D8%A8%D9%86%D8%A7%D8%A1_%D8%A7%D9%84%D8%AF%D9%88%D8%AD%D9%87', 'tweet_volume': None}, {'name': '#قوه_البرد', 'url': 'http://twitt ...
#
# [{'trends': [{'name': 'Jim Lehrer', 'url': 'http://twitter.com/search?q=%22Jim+Lehrer%22', 'promoted_content': None, 'query': '%22Jim+Lehrer%22', 'tweet_volume': 23892}, {'name': '#DoomsdayClock', 'url': 'http://twitter.com/search?q=%23DoomsdayClock', 'promoted_content': None, 'query': '%23DoomsdayClock', 'tweet_volume': 26289}, {'name': 'Prince Charles', 'url': 'http://twitter.com/search?q=%22Prince+Charles%22', 'promoted_content': None, 'query': '%22Prince+Charles%22', 'tweet_volume': 77274}, {'name': '#colourpop9milli', 'url': 'http://twitter.com/search?q=%23colourpop9milli', 'promoted_content': None, 'query': '%23colourpop9milli', 'tweet_volume': 11325}, {'name': '#NationalPieDay', 'url': 'http://twitter.com/search?q=%23NationalPieDay', 'promoted_content': None, 'query': '%23NationalPieDay', 'tweet_volume': 20254}, {'name': '#AskFunko', 'url': 'http://twitter.com/search?q=%23AskFunko', 'promoted_content': None, 'query': '%23AskFunko', 'tweet_volume': None}, {'name': '#WOLLIV', 'url': 'http://twitter.com/search?q=%23WOLLIV', 'promoted_content': None, 'query': '%23WOLLIV', 'tweet_volume': 33499}, {'name': 'Church of England', 'url': 'http://twitter.com/search?q=%22Church+of+England%22', 'promoted_content': None, 'query': '%22Church+of+England%22', 'tweet_volume': 17448}, {'name': 'Minamino', 'url': 'http://twitter.com/search?q=Minamino', 'promoted_content': None, 'query': 'Minamino', 'tweet_volume': None}, {'name': 'Mnuchin', 'url': 'http://twitter.com/search?q=Mnuchin', 'promoted_content': None, 'query': 'Mnuchin', 'tweet_volume': 68264}, {'name': 'James Corden', 'url': 'http://twitter.com/search?q=%22James+Corden%22', 'promoted_content': None, 'query': '%22James+Corden%22', 'tweet_volume': 151693}, {'name': 'Ebro', 'url': 'http://twitter.com/search?q=Ebro', 'promoted_content': None, 'query': 'Ebro', 'tweet_volume': None}, {'name': 'Fox Business', 'url': 'http://twitter.com/search?q=%22Fox+Business%22', 'promoted_content': None, 'query': '%22Fox+Business%22', 'tweet_volume': None}, {'name': "McDonald's All-American", 'url': 'http://twitter.com/search?q=%22McDonald%27s+All-American%22', 'promoted_content': None, 'query': '%22McDonald%27s+All-American%22', 'tweet_volume': None}, {'name': 'Andy Byford', 'url': 'http://twitter.com/search?q=%22Andy+Byford%22', 'promoted_content': None, 'query': '%22Andy+Byford%22', 'tweet_volume': None}, {'name': 'Netanyahu', 'url': 'http://twitter.com/search?q=Netanyahu', 'promoted_content': None, 'query': 'Netanyahu', 'tweet_volume': 47611}, {'name': 'MY BOO BY CNCO', 'url': 'http://twitter.com/search?q=%22MY+BOO+BY+CNCO%22', 'promoted_content': None, 'query': '%22MY+BOO+BY+CNCO%22', 'tweet_volume': 67995}, {'name': 'Ok Mack', 'url': 'http://twitter.com/search?q=%22Ok+Mack%22', 'promoted_content': None, 'query': '%22Ok+Mack%22', 'tweet_volume': None}, {'name': 'House of Balloons', 'url': 'http://twitter.com/search?q=%22House+of+Balloons%22', 'promoted_content': None, 'query': '%22House+of+Balloons%22', 'tweet_volume': None}, {'name': 'Mike Florio', 'url': 'http://twitter.com/search?q=%22Mike+Florio%22', 'promoted_content': None, 'query': '%22Mike+Florio%22', 'tweet_volume': None}, {'name': 'Lena Waithe', 'url': 'http://twitter.com/search?q=%22Lena+Waithe%22', 'promoted_content': None, 'query': '%22Lena+Waithe%22', 'tweet_volume': None}, {'name': 'Rep. Garcia', 'url': 'http://twitter.com/search?q=%22Rep.+Garcia%22', 'promoted_content': None, 'query': '%22Rep.+Garcia%22', 'tweet_volume': None}, {'name': 'Michelle Carter', 'url': 'http://twitter.com/search?q=%22Michelle+Carter%22', 'promoted_content': None, 'query': '%22Michelle+Carter%22', 'tweet_volume': None}, {'name': 'The Producers', 'url': 'http://twitter.com/search?q=%22The+Producers%22', 'promoted_content': None, 'query': '%22The+Producers%22', 'tweet_volume': None}, {'name': 'Carpool Karaoke', 'url': 'http://twitter.com/search?q=%22Carpool+Karaoke%22', 'promoted_content': None, 'query': '%22Carpool+Karaoke%22', 'tweet_volume': 134975}, { ...

# %%
import json

print(json.dumps(world_trends, indent=1))
#dumps dictionarys into json format
print()
print (json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#WOLLIV",
#     "url": "http://twitter.com/search?q=%23WOLLIV",
#     "promoted_content": null,
#     "query": "%23WOLLIV",
#     "tweet_volume": 33499
#    },
#    {
#     "name": "#coronovirus",
#     "url": "http://twitter.com/search?q=%23coronovirus",
#     "promoted_content": null,
#     "query": "%23coronovirus",
#     "tweet_volume": 90680
#    },
#    {
#     "name": "#RutoSpeaks",
#     "url": "http://twitter.com/search?q=%23RutoSpeaks",
#     "promoted_content": null,
#     "query": "%23RutoSpeaks",
#     "tweet_volume": 25569
#    },
#    {
#     "name": "#COAC2020P4",
#     "url": "http://twitter.com/search?q=%23COAC2020P4",
#     "promoted_content": null,
#     "query": "%23COAC2020P4",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ThankYouJimin",
#     "url": "http://twitter.com/search?q=%23ThankYouJimin",
#     "promoted_content": null,
#     "query": "%23ThankYouJimin",
#     "tweet_volume": 248515
#    },
#    {
#     "name": "Jim Lehrer",
#     "url": "http://twitter.com/search?q=%22Jim+Lehrer%22",
#     "promoted_content": null,
#     "query": "%22Jim+Lehrer%22",
#     "tweet_volume": 23892
#    },
#    {
#     "name": "Prince Charles",
#     "url": "http://twitter.com/search?q=%22Prince+Charles%22",
#     "promoted_content": null,
#     "query": "%22Prince+Charles%22",
#     "tweet_volume": 77274
#    },
#    {
#     "name": "Church of England",
#     "url": "http://twitter.com/search?q=%22Church+of+England%22",
#     "promoted_content": null,
#     "query": "%22Church+of+England%22",
#     "tweet_volume": 17448
#    },
#    {
#     "name": "MY BOO BY CNCO",
#     "url": "http://twitter.com/search?q=%22MY+BOO+BY+CNCO%22",
#     "promoted_content": null,
#     "query": "%22MY+BOO+BY+CNCO%22",
#     "tweet_volume": 67995
#    },
#    {
#     "name": "Damso",
#     "url": "http://twitter.com/search?q=Damso",
#     "promoted_content": null,
#     "query": "Damso",
#     "tweet_volume": 21172
#    },
#    {
#     "name": "#\u0627\u0644\u0627\u0647\u0644\u064a_\u0627\u0644\u0631\u0627\u064a\u062f_\u0627\u0644\u062f\u0648\u0631\u064a",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D8%A7%D9%84%D8%B1%D8%A7%D9%8A%D8%AF_%D8%A7%D9%84%D8%AF%D9%88%D8%B1%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%A7%D9%87%D9%84%D9%8A_%D8%A7%D9%84%D8%B1%D8%A7%D9%8A%D8%AF_%D8%A7%D9%84%D8%AF%D9%88%D8%B1%D9%8A",
#     "tweet_volume": 35349
#    },
#    {
#     "name": "#benimkahraman\u0131m",
#     "url": "http://twitter.com/search?q=%23benimkahraman%C4%B1m",
#     "promoted_content": null,
#     "query": "%23benimkahraman%C4%B1m",
#     "tweet_volume": 11101
#    },
#    {
#     "name": "#\u0627\u0644\u0634\u0628\u0627\u0628_\u0648\u0627\u0644\u0645",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B4%D8%A8%D8%A7%D8%A8_%D9%88%D8%A7%D9%84%D9%85",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%B4%D8%A8%D8%A7%D8%A8_%D9%88%D8%A7%D9%84%D9%85",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OTDirecto23E",
#     "url": "http://twitter.com/search?q=%23OTDirecto23E",
#     "promoted_content": null,
#     "query": "%23OTDirecto23E",
#     "tweet_volume": 103109
#    },
#    {
#     "name": "#colourpop9milli",
#     "url": "http://twitter.com/search?q=%23colourpop9milli",
#     "promoted_content": null,
#     "query": "%23colourpop9milli",
#     "tweet_volume": 11325
#    },
#    {
#     "name": "#DoomsdayClock",
#     "url": "http://twitter.com/search?q=%23DoomsdayClock",
#     "promoted_content": null,
#     "query": "%23DoomsdayClock",
#     "tweet_volume": 26289
#    },
#    {
#     "name": "#kupan\u0131nyolu",
#     "url": "http://twitter.com/search?q=%23kupan%C4%B1nyolu",
#     "promoted_content": null,
#     "query": "%23kupan%C4%B1nyolu",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OroBTSColombia",
#     "url": "http://twitter.com/search?q=%23OroBTSColombia",
#     "promoted_content": null,
#     "query": "%23OroBTSColombia",
#     "tweet_volume": 43196
#    },
#    {
#     "name": "#EverythingIWantedMusicVideo",
#     "url": "http://twitter.com/search?q=%23EverythingIWantedMusicVideo",
#     "promoted_content": null,
#     "query": "%23EverythingIWantedMusicVideo",
#     "tweet_volume": 14238
#    },
#    {
#     "name": "#DragRace",
#     "url": "http://twitter.com/search?q=%23DragRace",
#     "promoted_content": null,
#     "query": "%23DragRace",
#     "tweet_volume": 29618
#    },
#    {
#     "name": "#MasterChefIt",
#     "url": "http://twitter.com/search?q=%23MasterChefIt",
#     "promoted_content": null,
#     "query": "%23MasterChefIt",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0627\u0628\u0646\u0627\u0621_\u0627\u0644\u062f\u0648\u062d\u0647",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D8%A8%D9%86%D8%A7%D8%A1_%D8%A7%D9%84%D8%AF%D9%88%D8%AD%D9%87",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D8%A8%D9%86%D8%A7%D8%A1_%D8%A7%D9%84%D8%AF%D9%88%D8%AD%D9%87",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0642\u0648\u0647_\u0627\u0644\u0628\u0631\u062f",
#     "url": "http://twitter.com/search?q=%23%D9%82%D9%88%D9%87_%D8%A7%D9%84%D8%A8%D8%B1%D8%AF",
#     "promoted_content": null,
#     "query": "%23%D9%82%D9%88%D9%87_%D8%A7%D9%84%D8%A8%D8%B1%D8%AF",
#     "tweet_volume": 13940
#    },
#    {
#     "name": "#DonMatteo12",
#     "url": "http://twitter.com/search?q=%23DonMatteo12",
#     "promoted_content": null,
#     "query": "%23DonMatteo12",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GSvR\u0130Z",
#     "url": "http://twitter.com/search?q=%23GSvR%C4%B0Z",
#     "promoted_content": null,
#     "query": "%23GSvR%C4%B0Z",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TPMP",
#     "url": "http://twitter.com/search?q=%23TPMP",
#     "promoted_content": null,
#     "query": "%23TPMP",
#     "tweet_volume": 14859
#    },
#    {
#     "name": "#Nihat\u00d6zdemir\u0130stifa",
#     "url": "http://twitter.com/search?q=%23Nihat%C3%96zdemir%C4%B0stifa",
#     "promoted_content": null,
#     "query": "%23Nihat%C3%96zdemir%C4%B0stifa",
#     "tweet_volume": 23718
#    },
#    {
#     "name": "#NickiMinajIsComing",
#     "url": "http://twitter.com/search?q=%23NickiMinajIsComing",
#     "promoted_content": null,
#     "query": "%23NickiMinajIsComing",
#     "tweet_volume": 14081
#    },
#    {
#     "name": "#NationalPieDay",
#     "url": "http://twitter.com/search?q=%23NationalPieDay",
#     "promoted_content": null,
#     "query": "%23NationalPieDay",
#     "tweet_volume": 20254
#    },
#    {
#     "name": "#\u062f\u0642\u064a\u0642\u0647_\u0639\u0645\u0631",
#     "url": "http://twitter.com/search?q=%23%D8%AF%D9%82%D9%8A%D9%82%D9%87_%D8%B9%D9%85%D8%B1",
#     "promoted_content": null,
#     "query": "%23%D8%AF%D9%82%D9%8A%D9%82%D9%87_%D8%B9%D9%85%D8%B1",
#     "tweet_volume": null
#    },
#    {
#     "name": "#IHateWhenPeopleAsk",
#     "url": "http://twitter.com/search?q=%23IHateWhenPeopleAsk",
#     "promoted_content": null,
#     "query": "%23IHateWhenPeopleAsk",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AskFunko",
#     "url": "http://twitter.com/search?q=%23AskFunko",
#     "promoted_content": null,
#     "query": "%23AskFunko",
#     "tweet_volume": null
#    },
#    {
#     "name": "#nacpsv",
#     "url": "http://twitter.com/search?q=%23nacpsv",
#     "promoted_content": null,
#     "query": "%23nacpsv",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheRiseOfSidharth",
#     "url": "http://twitter.com/search?q=%23TheRiseOfSidharth",
#     "promoted_content": null,
#     "query": "%23TheRiseOfSidharth",
#     "tweet_volume": 1194113
#    },
#    {
#     "name": "#jackask",
#     "url": "http://twitter.com/search?q=%23jackask",
#     "promoted_content": null,
#     "query": "%23jackask",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CassacaoDeRodrigoMaiaJa",
#     "url": "http://twitter.com/search?q=%23CassacaoDeRodrigoMaiaJa",
#     "promoted_content": null,
#     "query": "%23CassacaoDeRodrigoMaiaJa",
#     "tweet_volume": 21018
#    },
#    {
#     "name": "#FreeDetainedIranianProtesters",
#     "url": "http://twitter.com/search?q=%23FreeDetainedIranianProtesters",
#     "promoted_content": null,
#     "query": "%23FreeDetainedIranianProtesters",
#     "tweet_volume": 87858
#    },
#    {
#     "name": "#Piazzapulita",
#     "url": "http://twitter.com/search?q=%23Piazzapulita",
#     "promoted_content": null,
#     "query": "%23Piazzapulita",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u092f\u094b\u0917\u0940_\u0926\u093f\u092e\u093e\u0917_\u0915\u093e_\u0930\u094b\u0917\u0940",
#     "url": "http://twitter.com/search?q=%23%E0%A4%AF%E0%A5%8B%E0%A4%97%E0%A5%80_%E0%A4%A6%E0%A4%BF%E0%A4%AE%E0%A4%BE%E0%A4%97_%E0%A4%95%E0%A4%BE_%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A5%80",
#     "promoted_content": null,
#     "query": "%23%E0%A4%AF%E0%A5%8B%E0%A4%97%E0%A5%80_%E0%A4%A6%E0%A4%BF%E0%A4%AE%E0%A4%BE%E0%A4%97_%E0%A4%95%E0%A4%BE_%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A5%80",
#     "tweet_volume": 72912
#    },
#    {
#     "name": "#\u0627\u0633\u062a\u063a\u0644\u0627\u0644_\u0643\u0646\u0642_\u0627\u0644\u0639\u0632\u064a\u0632\u064a\u0647",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D8%B3%D8%AA%D8%BA%D9%84%D8%A7%D9%84_%D9%83%D9%86%D9%82_%D8%A7%D9%84%D8%B9%D8%B2%D9%8A%D8%B2%D9%8A%D9%87",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D8%B3%D8%AA%D8%BA%D9%84%D8%A7%D9%84_%D9%83%D9%86%D9%82_%D8%A7%D9%84%D8%B9%D8%B2%D9%8A%D8%B2%D9%8A%D9%87",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0641\u0636\u064a\u062d\u0647_\u0627\u0628\u0644\u0647_\u0636\u062d\u064a",
#     "url": "http://twitter.com/search?q=%23%D9%81%D8%B6%D9%8A%D8%AD%D9%87_%D8%A7%D8%A8%D9%84%D9%87_%D8%B6%D8%AD%D9%8A",
#     "promoted_content": null,
#     "query": "%23%D9%81%D8%B6%D9%8A%D8%AD%D9%87_%D8%A7%D8%A8%D9%84%D9%87_%D8%B6%D8%AD%D9%8A",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0939\u0930_\u0926\u093f\u0932_\u092e\u0947\u0902_\u092f\u094b\u0917\u0940",
#     "url": "http://twitter.com/search?q=%23%E0%A4%B9%E0%A4%B0_%E0%A4%A6%E0%A4%BF%E0%A4%B2_%E0%A4%AE%E0%A5%87%E0%A4%82_%E0%A4%AF%E0%A5%8B%E0%A4%97%E0%A5%80",
#     "promoted_content": null,
#     "query": "%23%E0%A4%B9%E0%A4%B0_%E0%A4%A6%E0%A4%BF%E0%A4%B2_%E0%A4%AE%E0%A5%87%E0%A4%82_%E0%A4%AF%E0%A5%8B%E0%A4%97%E0%A5%80",
#     "tweet_volume": 53989
#    },
#    {
#     "name": "#LaIslaDeLasTentaciones5",
#     "url": "http://twitter.com/search?q=%23LaIslaDeLasTentaciones5",
#     "promoted_content": null,
#     "query": "%23LaIslaDeLasTentaciones5",
#     "tweet_volume": 16873
#    },
#    {
#     "name": "#BanaBirMasalAnlatFikret",
#     "url": "http://twitter.com/search?q=%23BanaBirMasalAnlatFikret",
#     "promoted_content": null,
#     "query": "%23BanaBirMasalAnlatFikret",
#     "tweet_volume": 11089
#    },
#    {
#     "name": "#\u0627\u0644\u0643\u0641\u064a\u0641_\u0639\u0628\u062f\u0627\u0644\u0644\u0647",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%83%D9%81%D9%8A%D9%81_%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D9%84%D9%87",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D9%83%D9%81%D9%8A%D9%81_%D8%B9%D8%A8%D8%AF%D8%A7%D9%84%D9%84%D9%87",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Acusaci\u00f3nConstitucional",
#     "url": "http://twitter.com/search?q=%23Acusaci%C3%B3nConstitucional",
#     "promoted_content": null,
#     "query": "%23Acusaci%C3%B3nConstitucional",
#     "tweet_volume": 10806
#    },
#    {
#     "name": "#\u0643\u0645_\u0645\u0628\u0644\u063a_\u064a\u0643\u0641\u064a_\u0645\u0634\u0631\u0648\u0639\u0643_\u0627\u0644\u062e\u0627\u0635",
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%85_%D9%85%D8%A8%D9%84%D8%BA_%D9%8A%D9%83%D9%81%D9%8A_%D9%85%D8%B4%D8%B1%D9%88%D8%B9%D9%83_%D8%A7%D9%84%D8%AE%D8%A7%D8%B5",
#     "promoted_content": null,
#     "query": "%23%D9%83%D9%85_%D9%85%D8%A8%D9%84%D8%BA_%D9%8A%D9%83%D9%81%D9%8A_%D9%85%D8%B4%D8%B1%D9%88%D8%B9%D9%83_%D8%A7%D9%84%D8%AE%D8%A7%D8%B5",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KenyaVsSouthAfrica",
#     "url": "http://twitter.com/search?q=%23KenyaVsSouthAfrica",
#     "promoted_content": null,
#     "query": "%23KenyaVsSouthAfrica",
#     "tweet_volume": null
#    },
#    {
#     "name": "#YeriWeLoveYou",
#     "url": "http://twitter.com/search?q=%23YeriWeLoveYou",
#     "promoted_content": null,
#     "query": "%23YeriWeLoveYou",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0635\u0627\u0631_\u0627\u0644\u0648\u0642\u062a",
#     "url": "http://twitter.com/search?q=%23%D8%B5%D8%A7%D8%B1_%D8%A7%D9%84%D9%88%D9%82%D8%AA",
#     "promoted_content": null,
#     "query": "%23%D8%B5%D8%A7%D8%B1_%D8%A7%D9%84%D9%88%D9%82%D8%AA",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-01-23T21:09:12Z",
#   "created_at": "2020-01-23T21:05:11Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "trends": [
#    {
#     "name": "Jim Lehrer",
#     "url": "http://twitter.com/search?q=%22Jim+Lehrer%22",
#     "promoted_content": null,
#     "query": "%22Jim+Lehrer%22",
#     "tweet_volume": 23892
#    },
#    {
#     "name": "#DoomsdayClock",
#     "url": "http://twitter.com/search?q=%23DoomsdayClock",
#     "promoted_content": null,
#     "query": "%23DoomsdayClock",
#     "tweet_volume": 26289
#    },
#    {
#     "name": "Prince Charles",
#     "url": "http://twitter.com/search?q=%22Prince+Charles%22",
#     "promoted_content": null,
#     "query": "%22Prince+Charles%22",
#     "tweet_volume": 77274
#    },
#    {
#     "name": "#colourpop9milli",
#     "url": "http://twitter.com/search?q=%23colourpop9milli",
#     "promoted_content": null,
#     "query": "%23colourpop9milli",
#     "tweet_volume": 11325
#    },
#    {
#     "name": "#NationalPieDay",
#     "url": "http://twitter.com/search?q=%23NationalPieDay",
#     "promoted_content": null,
#     "query": "%23NationalPieDay",
#     "tweet_volume": 20254
#    },
#    {
#     "name": "#AskFunko",
#     "url": "http://twitter.com/search?q=%23AskFunko",
#     "promoted_content": null,
#     "query": "%23AskFunko",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WOLLIV",
#     "url": "http://twitter.com/search?q=%23WOLLIV",
#     "promoted_content": null,
#     "query": "%23WOLLIV",
#     "tweet_volume": 33499
#    },
#    {
#     "name": "Church of England",
#     "url": "http://twitter.com/search?q=%22Church+of+England%22",
#     "promoted_content": null,
#     "query": "%22Church+of+England%22",
#     "tweet_volume": 17448
#    },
#    {
#     "name": "Minamino",
#     "url": "http://twitter.com/search?q=Minamino",
#     "promoted_content": null,
#     "query": "Minamino",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mnuchin",
#     "url": "http://twitter.com/search?q=Mnuchin",
#     "promoted_content": null,
#     "query": "Mnuchin",
#     "tweet_volume": 68264
#    },
#    {
#     "name": "James Corden",
#     "url": "http://twitter.com/search?q=%22James+Corden%22",
#     "promoted_content": null,
#     "query": "%22James+Corden%22",
#     "tweet_volume": 151693
#    },
#    {
#     "name": "Ebro",
#     "url": "http://twitter.com/search?q=Ebro",
#     "promoted_content": null,
#     "query": "Ebro",
#     "tweet_volume": null
#    },
#    {
#     "name": "Fox Business",
#     "url": "http://twitter.com/search?q=%22Fox+Business%22",
#     "promoted_content": null,
#     "query": "%22Fox+Business%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "McDonald's All-American",
#     "url": "http://twitter.com/search?q=%22McDonald%27s+All-American%22",
#     "promoted_content": null,
#     "query": "%22McDonald%27s+All-American%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Andy Byford",
#     "url": "http://twitter.com/search?q=%22Andy+Byford%22",
#     "promoted_content": null,
#     "query": "%22Andy+Byford%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Netanyahu",
#     "url": "http://twitter.com/search?q=Netanyahu",
#     "promoted_content": null,
#     "query": "Netanyahu",
#     "tweet_volume": 47611
#    },
#    {
#     "name": "MY BOO BY CNCO",
#     "url": "http://twitter.com/search?q=%22MY+BOO+BY+CNCO%22",
#     "promoted_content": null,
#     "query": "%22MY+BOO+BY+CNCO%22",
#     "tweet_volume": 67995
#    },
#    {
#     "name": "Ok Mack",
#     "url": "http://twitter.com/search?q=%22Ok+Mack%22",
#     "promoted_content": null,
#     "query": "%22Ok+Mack%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "House of Balloons",
#     "url": "http://twitter.com/search?q=%22House+of+Balloons%22",
#     "promoted_content": null,
#     "query": "%22House+of+Balloons%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mike Florio",
#     "url": "http://twitter.com/search?q=%22Mike+Florio%22",
#     "promoted_content": null,
#     "query": "%22Mike+Florio%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lena Waithe",
#     "url": "http://twitter.com/search?q=%22Lena+Waithe%22",
#     "promoted_content": null,
#     "query": "%22Lena+Waithe%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Rep. Garcia",
#     "url": "http://twitter.com/search?q=%22Rep.+Garcia%22",
#     "promoted_content": null,
#     "query": "%22Rep.+Garcia%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Michelle Carter",
#     "url": "http://twitter.com/search?q=%22Michelle+Carter%22",
#     "promoted_content": null,
#     "query": "%22Michelle+Carter%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Producers",
#     "url": "http://twitter.com/search?q=%22The+Producers%22",
#     "promoted_content": null,
#     "query": "%22The+Producers%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Carpool Karaoke",
#     "url": "http://twitter.com/search?q=%22Carpool+Karaoke%22",
#     "promoted_content": null,
#     "query": "%22Carpool+Karaoke%22",
#     "tweet_volume": 134975
#    },
#    {
#     "name": "Trapsoul",
#     "url": "http://twitter.com/search?q=Trapsoul",
#     "promoted_content": null,
#     "query": "Trapsoul",
#     "tweet_volume": 10481
#    },
#    {
#     "name": "Brazos County",
#     "url": "http://twitter.com/search?q=%22Brazos+County%22",
#     "promoted_content": null,
#     "query": "%22Brazos+County%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sadio",
#     "url": "http://twitter.com/search?q=Sadio",
#     "promoted_content": null,
#     "query": "Sadio",
#     "tweet_volume": null
#    },
#    {
#     "name": "Man\u00e9",
#     "url": "http://twitter.com/search?q=Man%C3%A9",
#     "promoted_content": null,
#     "query": "Man%C3%A9",
#     "tweet_volume": 61229
#    },
#    {
#     "name": "Annabella Sciorra",
#     "url": "http://twitter.com/search?q=%22Annabella+Sciorra%22",
#     "promoted_content": null,
#     "query": "%22Annabella+Sciorra%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ThursdayThoughts",
#     "url": "http://twitter.com/search?q=%23ThursdayThoughts",
#     "promoted_content": null,
#     "query": "%23ThursdayThoughts",
#     "tweet_volume": 89835
#    },
#    {
#     "name": "#nickiminajiscoming",
#     "url": "http://twitter.com/search?q=%23nickiminajiscoming",
#     "promoted_content": null,
#     "query": "%23nickiminajiscoming",
#     "tweet_volume": 14081
#    },
#    {
#     "name": "#jackask",
#     "url": "http://twitter.com/search?q=%23jackask",
#     "promoted_content": null,
#     "query": "%23jackask",
#     "tweet_volume": null
#    },
#    {
#     "name": "#comcastoutage",
#     "url": "http://twitter.com/search?q=%23comcastoutage",
#     "promoted_content": null,
#     "query": "%23comcastoutage",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WackyPickupLines",
#     "url": "http://twitter.com/search?q=%23WackyPickupLines",
#     "promoted_content": null,
#     "query": "%23WackyPickupLines",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DragRace",
#     "url": "http://twitter.com/search?q=%23DragRace",
#     "promoted_content": null,
#     "query": "%23DragRace",
#     "tweet_volume": 29618
#    },
#    {
#     "name": "#ThankYouJimin",
#     "url": "http://twitter.com/search?q=%23ThankYouJimin",
#     "promoted_content": null,
#     "query": "%23ThankYouJimin",
#     "tweet_volume": 248515
#    },
#    {
#     "name": "#CoronavirusOutbreak",
#     "url": "http://twitter.com/search?q=%23CoronavirusOutbreak",
#     "promoted_content": null,
#     "query": "%23CoronavirusOutbreak",
#     "tweet_volume": 34605
#    },
#    {
#     "name": "#VoteThemAllOut2020",
#     "url": "http://twitter.com/search?q=%23VoteThemAllOut2020",
#     "promoted_content": null,
#     "query": "%23VoteThemAllOut2020",
#     "tweet_volume": 36333
#    },
#    {
#     "name": "#WOTUS",
#     "url": "http://twitter.com/search?q=%23WOTUS",
#     "promoted_content": null,
#     "query": "%23WOTUS",
#     "tweet_volume": null
#    },
#    {
#     "name": "#IHateWhenPeopleAsk",
#     "url": "http://twitter.com/search?q=%23IHateWhenPeopleAsk",
#     "promoted_content": null,
#     "query": "%23IHateWhenPeopleAsk",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FauxCelebrityNews",
#     "url": "http://twitter.com/search?q=%23FauxCelebrityNews",
#     "promoted_content": null,
#     "query": "%23FauxCelebrityNews",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OneYearWithTXT",
#     "url": "http://twitter.com/search?q=%23OneYearWithTXT",
#     "promoted_content": null,
#     "query": "%23OneYearWithTXT",
#     "tweet_volume": 75758
#    },
#    {
#     "name": "#ThingsIWannaReboot",
#     "url": "http://twitter.com/search?q=%23ThingsIWannaReboot",
#     "promoted_content": null,
#     "query": "%23ThingsIWannaReboot",
#     "tweet_volume": null
#    },
#    {
#     "name": "#dollypartonchallenge",
#     "url": "http://twitter.com/search?q=%23dollypartonchallenge",
#     "promoted_content": null,
#     "query": "%23dollypartonchallenge",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Ambitions",
#     "url": "http://twitter.com/search?q=%23Ambitions",
#     "promoted_content": null,
#     "query": "%23Ambitions",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WBChat",
#     "url": "http://twitter.com/search?q=%23WBChat",
#     "promoted_content": null,
#     "query": "%23WBChat",
#     "tweet_volume": null
#    },
#    {
#     "name": "#loveforchance",
#     "url": "http://twitter.com/search?q=%23loveforchance",
#     "promoted_content": null,
#     "query": "%23loveforchance",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GallaHitched",
#     "url": "http://twitter.com/search?q=%23GallaHitched",
#     "promoted_content": null,
#     "query": "%23GallaHitched",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ShareYourFavSong_GOT7",
#     "url": "http://twitter.com/search?q=%23ShareYourFavSong_GOT7",
#     "promoted_content": null,
#     "query": "%23ShareYourFavSong_GOT7",
#     "tweet_volume": 90733
#    }
#   ],
#   "as_of": "2020-01-23T21:09:12Z",
#   "created_at": "2020-01-23T21:05:11Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %%
query = 'TWTR:' #chosen trend to search live tweets

count = 100 #number of recent tweets per page

search_results = twitter_api.search.tweets(q=query, count=count, result_types='recent')

statuses = search_results['statuses']
#iterates through batch of 300 tweets

#iterates through 5 more batches
for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except(KeyError): # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 201
# Length of statuses 201
# {
#  "created_at": "Fri Jan 24 16:35:01 +0000 2020",
#  "id": 1220746837226901504,
#  "id_str": "1220746837226901504",
#  "text": "$TWTR Warren Defends Student Loan Plan: Campaign Update via https://t.co/dU2ohMsCEH",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [
#    {
#     "text": "TWTR",
#     "indices": [
#      0,
#      5
#     ]
#    }
#   ],
#   "user_mentions": [],
#   "urls": [
#    {
#     "url": "https://t.co/dU2ohMsCEH",
#     "expanded_url": "http://www.hvper.com/?ref=s",
#     "display_url": "hvper.com/?ref=s",
#     "indices": [
#      60,
#      83
#     ]
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://finzine.com\" rel=\"nofollow\">Finzine</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 748817972970463232,
#   "id_str": "748817972970463232",
#   "name": "finzine",
#   "screen_name": "finzine",
#   "location": "",
#   "description": "News for Finance Enthusiasts.",
#   "url": "https://t.co/cBhvB9PtZH",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/cBhvB9PtZH",
#       "expanded_url": "http://finzine.com",
#       "display_url": "finzine.com",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 224,
#   "friends_count": 27,
#   "listed_count": 39,
#   "created_at": "Fri Jul 01 09:58:11 +0000 2016",
#   "favourites_count": 1,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 162553,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/773049871519580160/8fvfjObD_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/773049871519580160/8fvfjObD_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/748817972970463232/1473144457",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
len(search_results['statuses'])
# Out:
# 100

# %%
len(search_results)
# Out:
# 2

# %%
#print(search_results)

# %%
print(list(search_results.keys()))
# Out:
# ['statuses', 'search_metadata']

# %%
len(next_results)
# Out:
# 68

# %%
print(next_results)
# Out:
# ?max_id=1219283836435083264&q=Liverpool&count=100&include_entities=1

# %%
len(statuses)
# Out:
# 600

# %%
#store the tweets
with open('TWTR.json', 'w') as jsonfile:
    json.dump(statuses, jsonfile, indent=1)

# %% [markdown]
# ### Report some statistics about the tweets you collected
#
# * The topic of interest: Liverpool
#
#
# * The total number of tweets collected: 600

# %% [markdown]
# *-----------------------

# %% [markdown]
# # Problem 2: Analyzing Tweets and Tweet Entities with Frequency Analysis
#
# **1. Word Count:**
# * Use the tweets you collected in Problem 1, and compute the frequencies of the words being used in these tweets.
# * Plot a table of the top 30 words with their counts

# %%
#----------------------------------------------
with open('TWTR.json', 'r') as jsonfile:
    statuses_loaded = json.load(jsonfile)

#extracting text from the tweets
status_texts = [ status['text'] 
                 for status in statuses_loaded ]
#extracting screen names from the tweets
screen_names = [ user_mention['screen_name'] 
                 for status in statuses_loaded
                     for user_mention in status['entities']['user_mentions'] ]
#extracting hashtags from the tweets
hashtags = [ hashtag['text'] 
             for status in statuses_loaded
                 for hashtag in status['entities']['hashtags'] ]
#collect all words from all of the tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]
#print first 5 items for text and words
print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "$TWTR Warren Defends Student Loan Plan: Campaign Update via https://t.co/dU2ohMsCEH",
#  "Uff, ihr clippt nat\u00fcrlich die besten Stellen.. xD \nhttps://t.co/eSCLTBdMNS",
#  "@misonekn \u30de\u30c3\u30d7\u30ab\u30e1\u30e9\u306e\u30b5\u30a4\u30c8\u3067\u4e0b\u53d6\u4fa1\u683c\u3082\u78ba\u8a8d\u3067\u304d\u308b\u306e\u3067\u305c\u3072\u6bd4\u8f03\u3057\u3066\u3082\u3044\u3044\u304b\u3082\u3067\u3059\ud83d\udc4d",
#  "Eine ODE an die Starke Frau https://t.co/kIjbh0O8Cv",
#  "RT @Ericson_ubbhult: Turkiet g\u00e5r fr\u00e5n klarhet till klarhet...hur sjuka kan lagf\u00f6rslag bli? \ud83d\ude21\n\nIlskan i Turkiet \u2013 efter lagf\u00f6rslaget om sex\u2026"
# ]
# [
#  "$TWTR",
#  "Warren",
#  "Defends",
#  "Student",
#  "Loan"
# ]

# %%
print(statuses_loaded)
# Out:
# [{'created_at': 'Fri Jan 24 16:35:01 +0000 2020', 'id': 1220746837226901504, 'id_str': '1220746837226901504', 'text': '$TWTR Warren Defends Student Loan Plan: Campaign Update via https://t.co/dU2ohMsCEH', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [{'text': 'TWTR', 'indices': [0, 5]}], 'user_mentions': [], 'urls': [{'url': 'https://t.co/dU2ohMsCEH', 'expanded_url': 'http://www.hvper.com/?ref=s', 'display_url': 'hvper.com/?ref=s', 'indices': [60, 83]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://finzine.com" rel="nofollow">Finzine</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 748817972970463232, 'id_str': '748817972970463232', 'name': 'finzine', 'screen_name': 'finzine', 'location': '', 'description': 'News for Finance Enthusiasts.', 'url': 'https://t.co/cBhvB9PtZH', 'entities': {'url': {'urls': [{'url': 'https://t.co/cBhvB9PtZH', 'expanded_url': 'http://finzine.com', 'display_url': 'finzine.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 224, 'friends_count': 27, 'listed_count': 39, 'created_at': 'Fri Jul 01 09:58:11 +0000 2016', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 162553, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/773049871519580160/8fvfjObD_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/773049871519580160/8fvfjObD_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/748817972970463232/1473144457', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, {'created_at': 'Fri Jan 24 16:34:35 +0000 2020', 'id': 1220746729693372416, 'id_str': '1220746729693372416', 'text': 'Uff, ihr clippt natürlich die besten Stellen.. xD \nhttps://t.co/eSCLTBdMNS', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/eSCLTBdMNS', 'expanded_url': 'https://www.twitch.tv/zeora_/clip/FancyAstuteLaptopBCWarrior?tt_medium=twtr', 'display_url': 'twitch.tv/zeora_/clip/Fa…', 'indices': [51, 74]}]}, 'metadata': {'iso_language_code': 'de', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1173344655204921345, 'id_str': '1173344655204921345', 'name': 'Zeora', 'screen_name': 'ZeoraHS', 'location': 'Germany', 'description': 'Twitch Streamer and huge sushi lover, nomnom', 'url': 'https://t.co/Tgl55u1b3d', 'entities': {'url': {'urls': [{'url': 'https://t.co/Tgl55u1b3d', 'expanded_url': 'http://twitch.tv/zeora_', 'display_url': 'twitch.tv/zeora_', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 84, 'friends_count': 115, 'listed_count': 0, 'created_at': 'Sun Sep 15 21:15:57 +0000 2019', 'favourites_count': 247, 'utc_offset': None, 'time_zone': None, 'g ...

# %%
from collections import Counter
#creates frequency distribution from all of the words
# for item in [words]:
#     c = Counter(item)
#     print(c.most_common()[:30]) # top 10
#     print()

from prettytable import PrettyTable
# display tuples of words and count of words in a table using PrettyTable
for label, data in (('Word', words),):
    #for each word in words
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common(30) ]
    #add row with word and count
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print (pt)
# Out:
# +----------------+-------+
# | Word           | Count |
# +----------------+-------+
# | RT             |    73 |
# | i              |    33 |
# | twtr           |    24 |
# | att            |    23 |
# | gå             |    20 |
# | om             |    19 |
# | Turkiet        |    17 |
# | från           |    17 |
# | the            |    16 |
# | and            |    16 |
# | a              |    15 |
# | –              |    13 |
# | och            |    13 |
# | in             |    13 |
# | det            |    12 |
# | har            |    12 |
# | to             |    12 |
# | via            |    11 |
# | Ilskan         |    10 |
# | efter          |    10 |
# | lagförslaget   |    10 |
# | @Vera81343569: |    10 |
# | Finns          |    10 |
# | en             |    10 |
# | enda           |    10 |
# | frisk          |    10 |
# | person         |    10 |
# | Mp?🙄”–         |    10 |
# | Att            |    10 |
# | ut             |    10 |
# +----------------+-------+

# %% [markdown]
# **2. Find the most popular tweets in your collection of tweets**
#
# Please plot a table of the top 10 tweets that are the most popular among your collection, i.e., the tweets with the largest number of retweet counts.

# %%
#----------------------------------------------
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses_loaded 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# Slice off the first 10 from the sorted results (reverse = highest to lowest) and display 
# each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
#turn retweets into a set to remove duplicates

[ pt.add_row(row) for row in sorted(set(retweets), reverse=True)[:10] ]
# add a row containing the next tuple
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+-----------------+----------------------------------------------------+
# | Count | Screen Name     | Text                                               |
# +-------+-----------------+----------------------------------------------------+
# | 991   | W_Trigger_off   | RT @W_Trigger_off:                                 |
# |       |                 | 1月25日はB級・二宮隊のオペレーター、氷見亜季隊員の誕生日!! |
# |       |                 | 常に冷静かつ適正な判断が冴える氷見隊員！           |
# |       |                 | 普段のコミュニケーションから垣間見える彼女のクールな優しさと心配りが、実戦での円滑なサポートに結びつ |
# |       |                 | いているのでしょう！                               |
# |       |                 | #ワールド…                                         |
# | 286   | yukimaru_26     | RT @yukimaru_26: 同級生とお風呂に入る話②    １／２ |
# |       |                 | #創作百合 https://t.co/CPcbeuscfl                  |
# | 208   | hani_13s        | RT @hani_13s: ستظل تعاني حتماً عندما تفشل في حب     |
# |       |                 | ذاتك إلى حين إتخاذك للقرار الصائب                  |
# |       |                 | ( لامزيد من التنازلات نفسي أولاً  ) 👍🏼              |
# |       |                 | https://t.co/pZZlk…                                |
# | 176   | pwepets         | RT @pwepets: Akun baru nih. mo nyari temen         |
# |       |                 | Rt for twtr                                        |
# |       |                 | Rep for ig                                         |
# |       |                 | Jn d unfoll                                        |
# |       |                 |                                                    |
# |       |                 | #Mutualankuy                                       |
# |       |                 | #mutualanajadulusiapataujodoh                      |
# |       |                 | #mutualan                                          |
# | 126   | __beril_        | RT @__beril_: Bi Kactane Sevgili yapip             |
# |       |                 | Benden Başkasıyla Muhatap Olma                     |
# |       |                 | Ona Ment Yazma Şunu Yapma Bunu                     |
# |       |                 | Yapma Diyip Arkada Fındık Kıran                    |
# |       |                 | Tems…                                              |
# | 50    | anderslindberg  | RT @anderslindberg: Påmin mig, sa inte Löfven      |
# |       |                 | något om ansvaret för gängvåldet hos de som köper  |
# |       |                 | knark?                                             |
# |       |                 |                                                    |
# |       |                 | Sprängt Östermalmshus var                          |
# |       |                 | överklas…                                          |
# | 42    | atsuhinaaa      | RT @atsuhinaaa: atsuhina au where atsumu runs a    |
# |       |                 | fan twtr about hinata and always ends his twts     |
# |       |                 | with "shouyo is art". one day he twt "shouyo…      |
# | 32    | hellgrenmarie   | RT @hellgrenmarie: Man misshandlad och rånad i     |
# |       |                 | sitt hem. Det var   greve Carl Piper som rånades o |
# |       |                 | misshandlades.  Han är socialdemokrat...🙄…         |
# | 16    | Ericson_ubbhult | RT @Ericson_ubbhult: Turkiet går från klarhet till |
# |       |                 | klarhet...hur sjuka kan lagförslag bli? 😡          |
# |       |                 |                                                    |
# |       |                 | Ilskan i Turkiet – efter lagförslaget om sex…      |
# | 12    | Vera81343569    | RT @Vera81343569: Finns det en enda frisk person i |
# |       |                 | Mp?🙄”– Att gå ut och säga att Uppsala kommun har   |
# |       |                 | varnat tjejer från att gå ensamma på st…           |
# +-------+-----------------+----------------------------------------------------+

# %% [markdown]
# **3. Find the most popular Tweet Entities in your collection of tweets**
#
# Please plot a table of the top 10 hashtags, top 10 user mentions that are the most popular in your collection of tweets.

# %%
x = ["red", "blue", "red", "pink"]
c = Counter(x)
print(c)
print(c.most_common(1))
for k in y.keys():
    print(k)
# Out:
# Counter({'red': 2, 'blue': 1, 'pink': 1})
# [('red', 2)]
# charlu
# fdsf

# %%
#----------------------------------------------
from prettytable import PrettyTable

#Display tuples of (screen names, counts) and (hashtags, counts)
for label, data in ( 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    #for each name in screen_names and hashtag in hashtags
    #add a new row with the tuple displayed in the table
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [pt.add_row(kv) for kv in c.most_common(10)]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +-----------------+-------+
# | Screen Name     | Count |
# +-----------------+-------+
# | Tesla           |    28 |
# | elonmusk        |    18 |
# | ICannot_Enough  |    17 |
# | jimcramer       |    17 |
# | ValueAnalyst1   |    14 |
# | JayinShanghai   |    14 |
# | vincent13031925 |    13 |
# | markbspiegel    |    11 |
# | TeslaPodcast    |     9 |
# | ihors3          |     9 |
# +-----------------+-------+
# +-------------+-------+
# | Hashtag     | Count |
# +-------------+-------+
# | Tesla       |    36 |
# | TSLA        |    10 |
# | BMW         |     8 |
# | stockmarket |     8 |
# | Amazon      |     7 |
# | Top10       |     7 |
# | investing   |     6 |
# | finance     |     4 |
# | VW          |     4 |
# | Allergan    |     3 |
# +-------------+-------+

# %% [markdown]
# * ------------------------
#
# # Problem 3: Getting "All" friends and "All" followers of a popular user in twitter

# %% [markdown]
# * choose a popular twitter user who has many followers, such as "ladygaga".
# * Get the list of all friends and all followers of the twitter user.
# * Plot 20 out of the followers, plot their ID numbers and screen names in a table.
# * Plot 20 out of the friends (if the user has more than 20 friends), plot their ID numbers and screen names in a table.

# %%
import sys
import time
from urllib.request import URLError
from http.client import BadStatusLine
import json
import twitter

def make_twitter_request(twitter_api_func, max_errors=10, *args, **kw): 
    
    # A nested helper function that handles common HTTPErrors. Return an updated
    # value for wait_period if the problem is a 500 level error. Block until the
    # rate limit is reset if it's a rate limiting issue (429 error). Returns None
    # for 401 and 404 errors, which requires special handling by the caller.
    def handle_twitter_http_error(e, wait_period=2, sleep_when_rate_limited=True):
    
        if wait_period > 3600: # Seconds
            print >> sys.stderr, 'Too many retries. Quitting.'
            raise e
    
        # See https://dev.twitter.com/docs/error-codes-responses for common codes
    
        if e.e.code == 401:
            print >> sys.stderr, 'Encountered 401 Error (Not Authorized)'
            return None
        elif e.e.code == 404:
            print >> sys.stderr, 'Encountered 404 Error (Not Found)'
            return None
        elif e.e.code == 429: 
            print >> sys.stderr, 'Encountered 429 Error (Rate Limit Exceeded)'
            if sleep_when_rate_limited:
                print >> sys.stderr, "Retrying in 15 minutes...ZzZ..."
                sys.stderr.flush()
                time.sleep(60*15 + 5)
                print >> sys.stderr, '...ZzZ...Awake now and trying again.'
                return 2
            else:
                raise e # Caller must handle the rate limiting issue
        elif e.e.code in (500, 502, 503, 504):
            print >> sys.stderr, 'Encountered %i Error. Retrying in %i seconds' % \
                (e.e.code, wait_period)
            time.sleep(wait_period)
            wait_period *= 1.5
            return wait_period
        else:
            raise e

    # End of nested helper function
    
    wait_period = 2 
    error_count = 0 

    while True:
        try:
            return twitter_api_func(*args, **kw)
        except(twitter.api.TwitterHTTPError, e):
            error_count = 0 
            wait_period = handle_twitter_http_error(e, wait_period)
            if wait_period is None:
                return
        except(URLError, e):
            error_count += 1
            print >> sys.stderr, "URLError encountered. Continuing."
            if error_count > max_errors:
                print >> sys.stderr, "Too many consecutive errors...bailing out."
                raise
        except(BadStatusLine, e):
            error_count += 1
            print >> sys.stderr, "BadStatusLine encountered. Continuing."
            if error_count > max_errors:
                print >> sys.stderr, "Too many consecutive errors...bailing out."
                raise

# Sample usage

twitter_api = oauth_login()

# See https://dev.twitter.com/docs/api/1.1/get/users/lookup for 
# twitter_api.users.lookup

response = make_twitter_request(twitter_api.users.lookup, 
                                screen_name="WPI")

print(json.dumps(response, indent=1))
# Out:
# [
#  {
#   "id": 16687357,
#   "id_str": "16687357",
#   "name": "WPI",
#   "screen_name": "WPI",
#   "location": "Worcester, MA",
#   "description": "The global leader in project-based learning | A purpose-driven community of educators and researchers | An impact maker for higher ed & the world",
#   "url": "https://t.co/mN2pL8LiOT",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/mN2pL8LiOT",
#       "expanded_url": "http://www.wpi.edu",
#       "display_url": "wpi.edu",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 15874,
#   "friends_count": 5718,
#   "listed_count": 309,
#   "created_at": "Fri Oct 10 19:00:31 +0000 2008",
#   "favourites_count": 14010,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": true,
#   "statuses_count": 21176,
#   "lang": null,
#   "status": {
#    "created_at": "Fri Jan 24 14:39:34 +0000 2020",
#    "id": 1220717786382520320,
#    "id_str": "1220717786382520320",
#    "text": "RT @CubeTwentyThree: Was watching @adafruit 's \"Ask an Engineer\" tonight and saw some familiar names. @technocopia &amp; @WPI_Robotics  Alex Ca\u2026",
#    "truncated": false,
#    "entities": {
#     "hashtags": [],
#     "symbols": [],
#     "user_mentions": [
#      {
#       "screen_name": "CubeTwentyThree",
#       "name": "Cubicle23",
#       "id": 942568152587751426,
#       "id_str": "942568152587751426",
#       "indices": [
#        3,
#        19
#       ]
#      },
#      {
#       "screen_name": "adafruit",
#       "name": "adafruit industries",
#       "id": 20731304,
#       "id_str": "20731304",
#       "indices": [
#        34,
#        43
#       ]
#      },
#      {
#       "screen_name": "technocopia",
#       "name": "Technocopia",
#       "id": 3351279843,
#       "id_str": "3351279843",
#       "indices": [
#        102,
#        114
#       ]
#      },
#      {
#       "screen_name": "WPI_Robotics",
#       "name": "WPI Robotics",
#       "id": 120939749,
#       "id_str": "120939749",
#       "indices": [
#        121,
#        134
#       ]
#      }
#     ],
#     "urls": []
#    },
#    "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "retweeted_status": {
#     "created_at": "Thu Jan 23 02:02:42 +0000 2020",
#     "id": 1220164924061765633,
#     "id_str": "1220164924061765633",
#     "text": "Was watching @adafruit 's \"Ask an Engineer\" tonight and saw some familiar names. @technocopia &amp; @WPI_Robotics  Alex\u2026 https://t.co/F9sJZoFCoS",
#     "truncated": true,
#     "entities": {
#      "hashtags": [],
#      "symbols": [],
#      "user_mentions": [
#       {
#        "screen_name": "adafruit",
#        "name": "adafruit industries",
#        "id": 20731304,
#        "id_str": "20731304",
#        "indices": [
#         13,
#         22
#        ]
#       },
#       {
#        "screen_name": "technocopia",
#        "name": "Technocopia",
#        "id": 3351279843,
#        "id_str": "3351279843",
#        "indices": [
#         81,
#         93
#        ]
#       },
#       {
#        "screen_name": "WPI_Robotics",
#        "name": "WPI Robotics",
#        "id": 120939749,
#        "id_str": "120939749",
#        "indices": [
#         100,
#         113
#        ]
#       }
#      ],
#      "urls": [
#       {
#        "url": "https://t.co/F9sJZoFCoS",
#        "expanded_url": "https://twitter.com/i/web/status/1220164924061765633",
#        "display_url": "twitter.com/i/web/status/1\u2026",
#        "indices": [
#         121,
#         144
#        ]
#       }
#      ]
#     },
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 4,
#     "favorite_count": 9,
#     "favorited": false,
#     "retweeted": false,
#     "lang": "en"
#    },
#    "is_quote_status": false,
#    "retweet_count": 4,
#    "favorite_count": 0,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "en"
#   },
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "040F1A",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": true,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/912677354740359168/-UTJ428k_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/912677354740359168/-UTJ428k_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/16687357/1576159494",
#   "profile_link_color": "AC2B37",
#   "profile_sidebar_border_color": "DFDFDF",
#   "profile_sidebar_fill_color": "F3F3F3",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "can_media_tag": true,
#   "followed_by": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  }
# ]

# %%
#----------------------------------------------
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary

from prettytable import PrettyTable
from functools import partial
from sys import maxsize

def get_friends_followers_ids(twitter_api, screen_name=None, user_id=None,
                              friends_limit=maxsize, followers_limit=maxsize):
    
    # Must have either screen_name or user_id (logical xor)
    assert (screen_name != None) != (user_id != None), \
    "Must have screen_name or user_id, but not both"
    
    get_friends_ids = partial(make_twitter_request, twitter_api.friends.list, 
                              count=5000)
    get_followers_ids = partial(make_twitter_request, twitter_api.followers.list, 
                                count=5000)#how many to search at a time

    friends_ids, followers_ids = [], []
    
    for twitter_api_func, limit, ids, label in [
                    [get_friends_ids, friends_limit, friends_ids, "friends"], 
                    [get_followers_ids, followers_limit, followers_ids, "followers"]
                ]:
        
        if limit == 0: continue
        
        cursor = -1
        while cursor != 0:
        
            # Use make_twitter_request via the partially bound callable...
            if screen_name: 
                response = twitter_api_func(screen_name=screen_name, cursor=cursor)
            else: # user_id
                response = twitter_api_func(user_id=user_id, cursor=cursor)

            if response is not None:
                ids += response['users']
                cursor = response['next_cursor']
        
#             print >> sys.stderr, 'Fetched {0} total {1} ids for {2}'.format(len(ids), 
#                                                     label, (user_id or screen_name))
            print(f"Fetched {len(ids)} total {label} ids for {user_id or screen_name}")
        
            # XXX: You may want to store data during each iteration to provide an 
            # an additional layer of protection from exceptional circumstances
        
            if len(ids) >= limit or response is None:
                break

    # Do something useful with the IDs, like store them to disk...
    return friends_ids[:friends_limit], followers_ids[:followers_limit]
    # Sample usage

twitter_api = oauth_login()

friends_ids, followers_ids = get_friends_followers_ids(twitter_api, 
                                                       screen_name="JoejoeLotima", 
                                                       friends_limit=20, 
                                                       followers_limit=20)

friends_tuples = []
followers_tuples = []


for friend, follower in zip(friends_ids, followers_ids):
    friends_tuples.append((friend['id_str'],friend['screen_name']))
    followers_tuples.append((follower['id_str'],follower['screen_name']))

friends_pt = PrettyTable()
friends_pt.field_names = ['Friend ID', 'Friend Screen Name']

for friend_id, friend_screen_name in friends_tuples:
    friends_pt.add_row([friend_id, friend_screen_name])
        
friends_pt.align['Friend ID'], pt.align['Friend Screen Name'] = 'l', 'r' # Set column alignment

followers_pt = PrettyTable()
followers_pt.field_names = ['Follower ID', 'Follower Screen Name']

for follower_id, follower_screen_name in followers_tuples:
    followers_pt.add_row([follower_id, follower_screen_name])
        
followers_pt.align['Follower ID'], pt.align['Follower Screen Name'] = 'l', 'r' # Set column alignment

print(friends_pt)
print(followers_pt)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\twitter\api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     340         try:
# --> 341             handle = urllib_request.urlopen(req, **kwargs)
#     342             if handle.headers['Content-Type'] in ['image/jpeg', 'image/png']:
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 429: Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# TwitterHTTPError                          Traceback (most recent call last)
# <ipython-input-6-441b4e1732a8> in make_twitter_request(twitter_api_func, max_errors, *args, **kw)
#      53         try:
# ---> 54             return twitter_api_func(*args, **kw)
#      55         except(twitter.api.TwitterHTTPError, e):
#
# ~\Anaconda3\lib\site-packages\twitter\api.py in __call__(self, **kwargs)
#     333         else:
# --> 334             return self._handle_response(req, uri, arg_data, _timeout)
#     335
#
# ~\Anaconda3\lib\site-packages\twitter\api.py in _handle_response(self, req, uri, arg_data, _timeout)
#     366             else:
# --> 367                 raise TwitterHTTPError(e, uri, self.format, arg_data)
#     368
#
# TwitterHTTPError: Twitter sent status 429 for URL: 1.1/friends/list.json using parameters: (count=5000&cursor=-1&oauth_consumer_key=QoTiAk8g8Hm9Zhejyt1GxF9Bp&oauth_nonce=9890119558366996617&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1579887624&oauth_token=571213367-dPdnChuVRjwRHoqfH0pi15IbgGhJmRoKxJjrP9wD&oauth_version=1.0&screen_name=JoejoeLotima&oauth_signature=p3h51J73iyaxwPfh6emUJyK0I28%3D)
# details: {'errors': [{'message': 'Rate limit exceeded', 'code': 88}]}
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-bdcf35acb238> in <module>
#      61                                                        screen_name="JoejoeLotima",
#      62                                                        friends_limit=20,
# ---> 63                                                        followers_limit=20)
#      64
#      65 friends_tuples = []
#
# <ipython-input-39-bdcf35acb238> in get_friends_followers_ids(twitter_api, screen_name, user_id, friends_limit, followers_limit)
#      34             # Use make_twitter_request via the partially bound callable...
#      35             if screen_name:
# ---> 36                 response = twitter_api_func(screen_name=screen_name, cursor=cursor)
#      37             else: # user_id
#      38                 response = twitter_api_func(user_id=user_id, cursor=cursor)
#
# <ipython-input-6-441b4e1732a8> in make_twitter_request(twitter_api_func, max_errors, *args, **kw)
#      53         try:
#      54             return twitter_api_func(*args, **kw)
# ---> 55         except(twitter.api.TwitterHTTPError, e):
#      56             error_count = 0
#      57             wait_period = handle_twitter_http_error(e, wait_period)
#
# NameError: name 'e' is not defined

# %%
import json

# print(json.dumps(friends_ids, indent=1))
#dumps dictionarys into json format
print()
# print (json.dumps(followers_ids, indent=1))
#saves json dictionaries as a file
with open('friends_ids.json', 'w') as jsonfile:
    json.dump(friends_ids, jsonfile, indent=1)
with open('followers_ids.json', 'w') as jsonfile:
    json.dump(followers_ids, jsonfile, indent=1)
    
    
with open('friends_ids.json', 'r') as jsonfile:
    friends_loaded = json.load(jsonfile)
with open('followers_ids.json', 'r') as jsonfile:
    followers_loaded = json.load(jsonfile)

# %% [markdown]
# * Compute the mutual friends within the two groups, i.e., the users who are in both friend list and follower list, plot their ID numbers and screen names in a table

# %%
#----------------------------------------------
friends_set = set(friends_tuples)
followers_set = set(followers_tuples)
mutual_friends = friends_set.intersection(followers_set)
# print(followers_set)
print(friends_set)
print(followers_set)
print(len(mutual_friends))
print(mutual_friends)
# Out:
# 0
# set()

# %% [markdown]
# *------------------------
#
# # Problem 4: Business question
#
# Run some additional experiments with your data to gain familiarity with the twitter data and twitter API.
#
# * Come up with a business question that Twitter data could help answer.
# * Decribe the business case.
# * How could Twitter data help a company decide how to spend its resources.

# %%
#----------------------------------------------
def harvest_user_timeline(twitter_api, screen_name=None, user_id=None, max_results=1000):
     
    assert (screen_name != None) != (user_id != None), \
    "Must have screen_name or user_id, but not both"    
    
    kw = {  # Keyword args for the Twitter API call
        'count': 200,
        'trim_user': 'true',
        'include_rts' : 'true',
        'since_id' : 1
        }
    
    if screen_name:
        kw['screen_name'] = screen_name
    else:
        kw['user_id'] = user_id
        
    max_pages = 16
    results = []
    
    tweets = make_twitter_request(twitter_api.statuses.user_timeline, **kw)
    
    if tweets is None: # 401 (Not Authorized) - Need to bail out on loop entry
        tweets = []
        
    results += tweets
    
#     print >> sys.stderr, 'Fetched %i tweets' % len(tweets)
    
    page_num = 1
    
    # Many Twitter accounts have fewer than 200 tweets so you don't want to enter
    # the loop and waste a precious request if max_results = 200.
    
    # Note: Analogous optimizations could be applied inside the loop to try and 
    # save requests. e.g. Don't make a third request if you have 287 tweets out of 
    # a possible 400 tweets after your second request. Twitter does do some 
    # post-filtering on censored and deleted tweets out of batches of 'count', though,
    # so you can't strictly check for the number of results being 200. You might get
    # back 198, for example, and still have many more tweets to go. If you have the
    # total number of tweets for an account (by GET /users/lookup/), then you could 
    # simply use this value as a guide.
    
    if max_results == kw['count']:
        page_num = max_pages # Prevent loop entry
    
    while page_num < max_pages and len(tweets) > 0 and len(results) < max_results:
    
        # Necessary for traversing the timeline in Twitter's v1.1 API:
        # get the next query's max-id parameter to pass in.
        # See https://dev.twitter.com/docs/working-with-timelines.
        kw['max_id'] = min([ tweet['id'] for tweet in tweets]) - 1 
    
        tweets = make_twitter_request(twitter_api.statuses.user_timeline, **kw)
        results += tweets

#         print >> sys.stderr, 'Fetched %i tweets' % (len(tweets),)
    
        page_num += 1
        
#     print >> sys.stderr, 'Done fetching tweets'

    return results[:max_results]
    
# Sample usage

twitter_api = oauth_login()
tweets = harvest_user_timeline(twitter_api, screen_name="WPI", \
                               max_results=200)
# print(tweets)

# Save to MongoDB with save_to_mongo or a local file with save_json...
# json.dumps(tweets, indent=1)
with open('WPItweets.json', 'w') as jsonfile:
    json.dump(tweets, jsonfile, indent=1)

# %%
# with open('WPItweets.json', 'r') as jsonfile:
#     tweets_loaded = json.load(jsonfile)
# print(json.dumps(tweets_loaded, indent=1))

# %%
with open('WPItweets.json', 'r') as jsonfile:
    tweets_loaded = json.load(jsonfile)

#extracting text from the tweets
status_texts = [ status['text'] 
                 for status in tweets_loaded ]
#extracting screen names from the tweets
screen_names = [ user_mention['screen_name'] 
                 for status in tweets_loaded
                     for user_mention in status['entities']['user_mentions'] ]
#extracting hashtags from the tweets
hashtags = [ hashtag['text'] 
             for status in tweets_loaded
                 for hashtag in status['entities']['hashtags'] ]
#collect all words from all of the tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]
#print first 5 items for text and words
print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
print(tweets_loaded)
# Out:
# [
#  "RT @CubeTwentyThree: Was watching @adafruit 's \"Ask an Engineer\" tonight and saw some familiar names. @technocopia &amp; @WPI_Robotics  Alex Ca\u2026",
#  "Do graduates with project-based experience bring skills and approaches to their work that better prepare them for t\u2026 https://t.co/Ct0Ildaczv",
#  "RT @telegramdotcom: @WPI profs get grants to work on converting waste to fuel\nhttps://t.co/hglcZIpADR @TimkoEnergyLab @FulbrightSchlrs @Tei\u2026",
#  "RT @WPIAdvising: A huge thank you to our @WPI Faculty who attend the #sophoMORE Success Program's annual #Faculty and Fries event. Thanks f\u2026",
#  "Graduate Research Innovation Exchange is a marketplace where students across disciplines get to know each other and\u2026 https://t.co/6Pl8L7oznQ"
# ]
# [
#  "RT",
#  "@CubeTwentyThree:",
#  "Was",
#  "watching",
#  "@adafruit"
# ]
# [{'created_at': 'Fri Jan 24 14:39:34 +0000 2020', 'id': 1220717786382520320, 'id_str': '1220717786382520320', 'text': 'RT @CubeTwentyThree: Was watching @adafruit \'s "Ask an Engineer" tonight and saw some familiar names. @technocopia &amp; @WPI_Robotics  Alex Ca…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'CubeTwentyThree', 'name': 'Cubicle23', 'id': 942568152587751426, 'id_str': '942568152587751426', 'indices': [3, 19]}, {'screen_name': 'adafruit', 'name': 'adafruit industries', 'id': 20731304, 'id_str': '20731304', 'indices': [34, 43]}, {'screen_name': 'technocopia', 'name': 'Technocopia', 'id': 3351279843, 'id_str': '3351279843', 'indices': [102, 114]}, {'screen_name': 'WPI_Robotics', 'name': 'WPI Robotics', 'id': 120939749, 'id_str': '120939749', 'indices': [121, 134]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 16687357, 'id_str': '16687357'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Jan 23 02:02:42 +0000 2020', 'id': 1220164924061765633, 'id_str': '1220164924061765633', 'text': 'Was watching @adafruit \'s "Ask an Engineer" tonight and saw some familiar names. @technocopia &amp; @WPI_Robotics  Alex… https://t.co/F9sJZoFCoS', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'adafruit', 'name': 'adafruit industries', 'id': 20731304, 'id_str': '20731304', 'indices': [13, 22]}, {'screen_name': 'technocopia', 'name': 'Technocopia', 'id': 3351279843, 'id_str': '3351279843', 'indices': [81, 93]}, {'screen_name': 'WPI_Robotics', 'name': 'WPI Robotics', 'id': 120939749, 'id_str': '120939749', 'indices': [100, 113]}], 'urls': [{'url': 'https://t.co/F9sJZoFCoS', 'expanded_url': 'https://twitter.com/i/web/status/1220164924061765633', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 942568152587751426, 'id_str': '942568152587751426'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 4, 'favorite_count': 9, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 4, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, {'created_at': 'Fri Jan 24 14:38:48 +0000 2020', 'id': 1220717593138352128, 'id_str': '1220717593138352128', 'text': 'Do graduates with project-based experience bring skills and approaches to their work that better prepare them for t… https://t.co/Ct0Ildaczv', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Ct0Ildaczv', 'expanded_url': 'https://twitter.com/i/web/status/1220717593138352128', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 16687357, 'id_str': '16687357'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1220685296439910401, 'quoted_status_id_str': '1220685296439910401', 'quoted_status': {'created_at': 'Fri Jan 24 12:30:28 +0000 2020', 'id': 1220685296439910401, 'id_str': '1220685296439910401', 'text': 'On @WPI Week: Project-based learning can set students up for success outside of school.\n\ ...

# %%
retweets = [
            # Store out a tuple of these three values ...
            (tweets['retweet_count'],
             tweets['text']) 
            
            # ... for each status ...
            for tweets in tweets_loaded 
            
            # ... so long as the status meets this condition.
                if 'retweet_count' in tweets
           ]

favorites = [
            # Store out a tuple of these three values ...
            (tweets['favorite_count'],
             tweets['text']) 
            
            # ... for each status ...
            for tweets in tweets_loaded 
            
            # ... so long as the status meets this condition.
                if 'favorite_count' in tweets
           ]

# Slice off the first 10 from the sorted results and display 
# each item in the tuple

pt_retweet = PrettyTable(field_names=['Retweet Count', 'Text'])
#turn retweets into a set to remove duplicates
# print(retweets)
[ pt_retweet.add_row(row) for row in sorted(retweets, reverse=True)[:10] ]
# add a row containing the next tuple
pt_retweet.max_width['Text'] = 50
pt_retweet.align= 'l'
print(pt_retweet)

pt_favorite = PrettyTable(field_names=['Favorite Count', 'Text'])
#turn retweets into a set to remove duplicates
# print(retweets)
[ pt_favorite.add_row(row) for row in sorted(favorites, reverse=True)[:10] ]
# add a row containing the next tuple
pt_favorite.max_width['Text'] = 50
pt_favorite.align= 'l'
print(pt_favorite)
# Out:
# +---------------+----------------------------------------------------+
# | Retweet Count | Text                                               |
# +---------------+----------------------------------------------------+
# | 10            | Congratulations to the newly accepted members of   |
# |               | the Class of #WPI2024!                             |
# |               |                                                    |
# |               | https://t.co/TM7Mh1B7fs https://t.co/XwCi0kqk0O    |
# | 8             | Using $2M grant from @Energy, @TimkoEnergyLab is   |
# |               | working on #research to one day enable energy-     |
# |               | producing companies… https://t.co/BQ3tHrdgsC       |
# | 8             | No matter what weather New England throws our way  |
# |               | (after all, who knows which season each of these   |
# |               | were taken in),… https://t.co/A4EAZ5IxkI           |
# | 8             | Implementation of the #WPIPlan 50 years ago was    |
# |               | many things: tense, frustrating, exhilarating, but |
# |               | most of all, rev… https://t.co/rz7nfzCgF7          |
# | 7             | What’s our formula for success that leads to 95%   |
# |               | of our graduates employed or in graduate school    |
# |               | shortly after grad… https://t.co/jEppEcyHaj        |
# | 7             | WPI students help young African immigrants chart   |
# |               | their paths to the future through the local        |
# |               | nonprofit… https://t.co/znXoXdcgdQ                 |
# | 7             | Road salt eating your car? WPI was awarded a $1.5M |
# |               | grant from @ENERGY Vehicle Technologies Office to  |
# |               | test to see if… https://t.co/pGdKly8pPF            |
# | 7             | RT @telegramdotcom: #Worcester airport giving away |
# |               | tickets to local college students                  |
# |               | https://t.co/mn12WEOPjw @FlyWorcester @WPI         |
# |               | @ClarkUnive…                                       |
# | 7             | RT @WBJournal: WPI opens $17M facility             |
# |               |                                                    |
# |               | https://t.co/o5MDqo1xqZ                            |
# | 7             | RT @Mass_Tech: .@WPI President @LaurieofMars kicks |
# |               | off the launch event for the PracticePoint health  |
# |               | technology lab. Cites the need for R&amp;D…        |
# +---------------+----------------------------------------------------+
# +----------------+----------------------------------------------------+
# | Favorite Count | Text                                               |
# +----------------+----------------------------------------------------+
# | 100            | Congratulations to the newly accepted members of   |
# |                | the Class of #WPI2024!                             |
# |                |                                                    |
# |                | https://t.co/TM7Mh1B7fs https://t.co/XwCi0kqk0O    |
# | 59             | #HappyHolidays https://t.co/yAR85msPwk             |
# | 44             | No matter where your travels take you over winter  |
# |                | break, you are wished a peaceful and happy holiday |
# |                | season from al… https://t.co/AB3uG68vTm            |
# | 37             | Welcome to our #winter wonderland!                 |
# |                | https://t.co/9EfdMMCKP8                            |
# | 33             | What’s our formula for success that leads to 95%   |
# |                | of our graduates employed or in graduate school    |
# |                | shortly after grad… https://t.co/jEppEcyHaj        |
# | 33             | Using $2M grant from @Energy, @TimkoEnergyLab is   |
# |                | working on #research to one day enable energy-     |
# |                | producing companies… https://t.co/BQ3tHrdgsC       |
# | 30             | No matter what weather New England throws our way  |
# |                | (after all, who knows which season each of these   |
# |                | were taken in),… https://t.co/A4EAZ5IxkI           |
# | 30             | Congrats professor Michael Timko of the            |
# |                | @TimkoEnergyLab for being selected as Blue Ribbon  |
# |                | finalist for the @NSF 202… https://t.co/vK13IEJ2lz |
# | 29             | Visually impaired WPI student featured in @usnews  |
# |                | for finding 'different path' as #engineer.         |
# |                | https://t.co/ih296syYOK https://t.co/BOCZ2bv8nJ    |
# | 25             | We are here for you. A Term, B Term, C Term, D     |
# |                | Term, E Term, Holiday Break, the weekends, the     |
# |                | Holidays... 365 days… https://t.co/E9qqDoKbOO      |
# +----------------+----------------------------------------------------+

# %% [markdown]
# *-----------------
# # Done
#
# All set!
#
# ** What do you need to submit?**
#
# * **Notebook File**: Save this IPython notebook, and find the notebook file in your folder (for example, "filename.ipynb"). This is the file you need to submit. Please make sure all the plotted tables and figures are in the notebook. If you used "ipython notebook --pylab=inline" to open the notebook, all the figures and tables should have shown up in the notebook.
#
#
# * **PPT Slides**: please prepare PPT slides (for 15 minutes' talk) to present about the case study . We will ask two teams which are randomly selected to present their case studies in class for this case study.
#
# * ** Report**: please prepare a report (less than 10 pages) to report what you found in the data.
#     * What data you collected?
#     * Why this topic is interesting or important to you? (Motivations)
#     * How did you analyse the data?
#     * What did you find in the data?
#
#      (please include figures or tables in the report, but no source code)
#
# Please compress all the files in a zipped file.
#
#
# ** How to submit: **
#
#         Please submit through email to Prof. Paffenroth (rcpaffenroth@wpi.edu).
#
# #### We auto-process the submissions so make sure your subject line is *exactly*:
#
# ### DS3010 Case Study 1 Team ??
#
# #### where ?? is your team number.
#
# ** Note: Each team just needs to submits one submission **

# %% [markdown]
# # Grading Criteria:
#
# ** Totoal Points: 100 **
#
#
# ---------------------------------------------------------------------------
# ** Notebook results:  **
#     Points: 80
#
#
#     -----------------------------------
#     Qestion 1:
#     Points: 20
#     -----------------------------------
#
#     (1) Select a topic that you are interested in.
#     Points: 6
#
#     (2) Use Twitter Streaming API to sample a collection of tweets about this topic in real time. (It would be recommended that the number of tweets should be larger than 200, but smaller than 1 million. Please check whether the total number of tweets collected is larger than 200?
#     Points: 10
#
#
#     (3) Store the tweets you downloaded into a local file (txt file or json file)
#     Points: 4
#
#
#     -----------------------------------
#     Qestion 2:
#     Points: 20
#     -----------------------------------
#
#     1. Word Count
#
#     (1) Use the tweets you collected in Problem 1, and compute the frequencies of the words being used in these tweets.
#     Points: 4
#
#     (2) Plot a table of the top 30 words with their counts
#     Points: 4
#
#     2. Find the most popular tweets in your collection of tweets
#     plot a table of the top 10 tweets that are the most popular among your collection, i.e., the tweets with the largest number of retweet counts.
#     Points: 4
#
#     3. Find the most popular Tweet Entities in your collection of tweets
#
#     (1) plot a table of the top 10 hashtags,
#     Points: 4
#
#     (2) top 10 user mentions that are the most popular in your collection of tweets.
#     Points: 4
#
#
#     -----------------------------------
#     Qestion 3:
#     Points: 20
#     -----------------------------------
#
#     (1) choose a popular twitter user who has many followers, such as "ladygaga".
#     Points: 4
#
#     (2) Get the list of all friends and all followers of the twitter user.
#     Points: 4
#
#     (3) Plot 20 out of the followers, plot their ID numbers and screen names in a table.
#     Points: 4
#
#     (4) Plot 20 out of the friends (if the user has more than 20 friends), plot their ID numbers and screen names in a table.
#     Points: 4
#
#     (5) Compute the mutual friends within the two groups, i.e., the users who are in both friend list and follower list, plot their ID numbers and screen names in a table
#     Points: 4
#
#     -----------------------------------
#     Qestion 4:  Business question
#     Points: 20
#     -----------------------------------
#         Novelty: 10
#         Interestingness: 10
#     -----------------------------------
#     Run some additional experiments with your data to gain familiarity with the twitter data ant twitter API.  Come up with a business question and describe how Twitter data can help you answer that question.
#
#
#
#
#
# ---------------------------------------------------------------------------
# ** Slides (for 10 minutes of presentation): Story-telling **
#     Points: 20
#
#
# 1. Motivation about the data collection, why the topic is interesting to you.
#     Points: 5
#
# 2. Communicating Results (figure/table)
#     Points: 10
#
# 3. Story telling (How all the parts (data, analysis, result) fit together as a story?)
#     Points: 5
